# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd /content/yolov5
# !pip install -U -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !python train.py --img 640 --batch 8 --epochs 10 --data /content/customPath.yaml --weights yolov5l.pt
# Out:
# 2023-11-27 14:54:52.746565: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 14:54:52.746629: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 14:54:52.746669: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from IPython.display import display, Image

# %%
Image(filename=f'/content/yolov5/runs/train/exp/results.png', width=600)

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --img-size 640 --source "/content/drive/MyDrive/CSE499G3.v2i.yolov8/test/images" --conf 0.5 --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/CSE499G3.v2i.yolov8/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46129818 parameters, 0 gradients, 107.7 GFLOPs
# image 1/75 /content/drive/.shortcut-targets-by-id/1aUq_ZAgu3ofJXYaDksCViyWb3JAOvUBb/CSE499G3.v2i.yolov8/test/images/hurricane-florence_00000029_post_disaster_png.rf.d55b361f4004f2f75ed7a3bbbceb6638.jpg: 640x640 1 major-damage, 49.7ms
# ...

# %%
from google.colab import drive, files
import os
import zipfile

# %%
# Specify the folder path in your Google Drive
folder_path = '/content/yolov5/runs/detect/exp3'

# List all files in the folder
file_list = os.listdir(folder_path)


# Create a zip file with all the files
zip_file_path = '/content/files.zip'
with zipfile.ZipFile(zip_file_path, 'w') as zip_file:
    for file_name in file_list:
        file_path = os.path.join(folder_path, file_name)
        print(f'Zipping: {file_name}')
        zip_file.write(file_path, os.path.basename(file_path))

# Download the zip file
files.download(zip_file_path)
# Out:
# Zipping: hurricane-harvey_00000143_post_disaster_png.rf.d71b944752251a686872c78755ded310.jpg
# Zipping: hurricane-harvey_00000185_post_disaster_png.rf.aec7f2a78f8df6e6f79809e09494b30e.jpg
# Zipping: hurricane-harvey_00000037_post_disaster_png.rf.01c7d1395c6318c85b5913bc2150ff8f.jpg
# Zipping: hurricane-michael_00000316_post_disaster_png.rf.080f2e95f0ed469cca96db10a7b67f74.jpg
# Zipping: midwest-flooding_00000286_post_disaster_png.rf.0a9c8943a86a1a3083409c1c45178a09.jpg
# Zipping: hurricane-harvey_00000468_post_disaster_png.rf.79675c3a17ceb16ff78214a02fdefd88.jpg
# Zipping: hurricane-florence_00000471_post_disaster_png.rf.dab81d205d2402ece62e6b0307a87dbf.jpg
# Zipping: mexico-earthquake_00000188_post_disaster_png.rf.7975437c41c754873fbed38d02309c8f.jpg
# Zipping: hurricane-michael_00000507_post_disaster_png.rf.5970f7fbb20d9e317c0b2e8a573e4558.jpg
# Zipping: hurricane-florence_00000113_post_disaster_png.rf.7dc5f640c87e8d5f80acd5ecc9a61e8e.jpg
# ...

# %%
# Specify the folder path in your Google Drive
folder_path = '/content/yolov5/runs/detect/exp3/labels'

# List all files in the folder
file_list = os.listdir(folder_path)


# Create a zip file with all the files
zip_file_path = '/content/files.zip'
with zipfile.ZipFile(zip_file_path, 'w') as zip_file:
    for file_name in file_list:
        file_path = os.path.join(folder_path, file_name)
        print(f'Zipping: {file_name}')
        zip_file.write(file_path, os.path.basename(file_path))

# Download the zip file
files.download(zip_file_path)
# Out:
# Zipping: hurricane-florence_00000095_post_disaster_png.rf.f73f35aca907507354d229c3f365ca3c.txt
# Zipping: hurricane-harvey_00000105_post_disaster_png.rf.882ae60bbcf4010b3f004bef7d6ce65d.txt
# Zipping: midwest-flooding_00000006_post_disaster_png.rf.0af7aaf1eddd2f75d84eec35ec50df4b.txt
# Zipping: hurricane-florence_00000480_post_disaster_png.rf.489f0ffc44eddc64bd7b9d265fcfec8b.txt
# Zipping: hurricane-florence_00000179_post_disaster_png.rf.897c55ec49ae4083e0332a379529e6c1.txt
# Zipping: hurricane-florence_00000208_post_disaster_png.rf.794cca9dbc1dc1aaeb1e38665494bf1d.txt
# Zipping: hurricane-michael_00000436_post_disaster_png.rf.ccc36856bb1c74965c9e00aaac3f1a20.txt
# Zipping: hurricane-florence_00000141_post_disaster_png.rf.1b021493eaedc688e0098ced6de59091.txt
# Zipping: hurricane-michael_00000138_post_disaster_png.rf.0f5cbf87084f0364c687c262c0072504.txt
# Zipping: hurricane-florence_00000076_post_disaster_png.rf.2c48882b98ae27f06971bf4d842a7c97.txt
# ...
